# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/customers_dataset.csv")
customers_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_98c22_row0_col0, #T_98c22_row0_col1, #T_98c22_row0_col2, #T_98c22_row0_col3, #T_98c22_row0_col4, #T_98c22_row1_col0, #T_98c22_row1_col1, #T_98c22_row1_col2, #T_98c22_row1_col3, #T_98c22_row1_col4, #T_98c22_row2_col0, #T_98c22_row2_col1, #T_98c22_row2_col2, #T_98c22_row2_col3, #T_98c22_row2_col4, #T_98c22_row3_col0, #T_98c22_row3_col1, #T_98c22_row3_col2, #T_98c22_row3_col3, #T_98c22_row3_col4, #T_98c22_row4_col0, #T_98c22_row4_col1, #T_98c22_row4_col2, #T_98c22_row4_col3, #T_98c22_row4_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_98c22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98c22_level0_col0" class="col_heading level0 col0" >customer_id</th>
#       <th id="T_98c22_level0_col1" class="col_heading level0 col1" >customer_unique_id</th>
#       <th id="T_98c22_level0_col2" class="col_heading level0 col2" >customer_zip_code_prefix</th>
# ...

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
seller_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/sellers_dataset.csv")
seller_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_e0d21_row0_col0, #T_e0d21_row0_col1, #T_e0d21_row0_col2, #T_e0d21_row0_col3, #T_e0d21_row1_col0, #T_e0d21_row1_col1, #T_e0d21_row1_col2, #T_e0d21_row1_col3, #T_e0d21_row2_col0, #T_e0d21_row2_col1, #T_e0d21_row2_col2, #T_e0d21_row2_col3, #T_e0d21_row3_col0, #T_e0d21_row3_col1, #T_e0d21_row3_col2, #T_e0d21_row3_col3, #T_e0d21_row4_col0, #T_e0d21_row4_col1, #T_e0d21_row4_col2, #T_e0d21_row4_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_e0d21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0d21_level0_col0" class="col_heading level0 col0" >seller_id</th>
#       <th id="T_e0d21_level0_col1" class="col_heading level0 col1" >seller_zip_code_prefix</th>
#       <th id="T_e0d21_level0_col2" class="col_heading level0 col2" >seller_city</th>
#       <th id="T_e0d21_level0_col3" class="col_heading level0 col3" >seller_state</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller_df.seller_city.value_counts()
# Out:
# seller_city
# sao paulo              694
# curitiba               127
# rio de janeiro          96
# belo horizonte          68
# ribeirao preto          52
#                       ...
# taruma                   1
# s jose do rio preto      1
# domingos martins         1
# messias targino          1
# leme                     1
# Name: count, Length: 611, dtype: int64

# %%
seller_df.seller_state.value_counts()
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# RN       5
# MS       5
# MT       4
# RO       2
# SE       2
# PI       1
# AC       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64

# %%
print("Jumlah duplikasi: ", seller_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
seller_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
seller_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
orderset_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/orders_dataset.csv")
orderset_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_ec0bd_row0_col0, #T_ec0bd_row0_col1, #T_ec0bd_row0_col2, #T_ec0bd_row0_col3, #T_ec0bd_row0_col4, #T_ec0bd_row0_col5, #T_ec0bd_row0_col6, #T_ec0bd_row0_col7, #T_ec0bd_row1_col0, #T_ec0bd_row1_col1, #T_ec0bd_row1_col2, #T_ec0bd_row1_col3, #T_ec0bd_row1_col4, #T_ec0bd_row1_col5, #T_ec0bd_row1_col6, #T_ec0bd_row1_col7, #T_ec0bd_row2_col0, #T_ec0bd_row2_col1, #T_ec0bd_row2_col2, #T_ec0bd_row2_col3, #T_ec0bd_row2_col4, #T_ec0bd_row2_col5, #T_ec0bd_row2_col6, #T_ec0bd_row2_col7, #T_ec0bd_row3_col0, #T_ec0bd_row3_col1, #T_ec0bd_row3_col2, #T_ec0bd_row3_col3, #T_ec0bd_row3_col4, #T_ec0bd_row3_col5, #T_ec0bd_row3_col6, #T_ec0bd_row3_col7, #T_ec0bd_row4_col0, #T_ec0bd_row4_col1, #T_ec0bd_row4_col2, #T_ec0bd_row4_col3, #T_ec0bd_row4_col4, #T_ec0bd_row4_col5, #T_ec0bd_row4_col6, #T_ec0bd_row4_col7 {
#   text-align: center;
# }
# </style>
# <table id="T_ec0bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
orderset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orderset_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]
 
for column in datetime_columns:
  orderset_df[column] = pd.to_datetime(orderset_df[column])

# %%
print("Jumlah duplikasi: ", orderset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orderset_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orderset_df.order_delivered_customer_date.value_counts()
# Out:
# order_delivered_customer_date
# 2018-05-08 23:38:46    3
# 2016-10-27 17:32:07    3
# 2018-02-14 21:09:19    3
# 2017-06-19 18:47:51    3
# 2018-05-08 19:36:48    3
#                       ..
# 2018-07-12 17:48:45    1
# 2018-05-18 18:24:36    1
# 2018-01-17 13:29:13    1
# 2018-06-29 11:21:34    1
# 2018-03-16 13:08:30    1
# Name: count, Length: 95664, dtype: int64

# %%
orderset_df[orderset_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orderset_df.order_delivered_customer_date.fillna(value="2018-10-17 13:22:46", inplace=True)

# %%
orderset_df.order_approved_at.fillna(value="2018-09-03 17:40:06", inplace=True)

# %%
orderset_df.order_delivered_carrier_date.fillna(value="2018-09-11 19:48:28", inplace=True)

# %%
orderset_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
orderset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99441 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  6   order_delivered_customer_date  99441 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orderset_df.describe()
# Out:
#             order_purchase_timestamp              order_approved_at  \
# count                          99441                          99441
# mean   2017-12-31 08:43:12.776581120  2018-01-01 04:05:16.967980800
# min              2016-09-04 21:15:19            2016-09-15 12:16:38
# 25%              2017-09-12 14:46:19            2017-09-13 03:35:20
# 50%              2018-01-18 23:04:36            2018-01-19 17:42:49
# 75%              2018-05-04 15:42:16            2018-05-05 09:55:24
# max              2018-10-17 17:30:18            2018-09-03 17:40:06
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                          99441                          99441
# mean   2018-01-09 09:22:30.571414272  2018-01-22 17:41:50.800404480
# min              2016-10-08 10:34:01            2016-10-11 13:46:32
# 25%              2017-09-19 19:52:27            2017-10-01 16:54:44
# 50%              2018-01-29 12:18:58            2018-02-09 20:41:37
# ...

# %%
print("Jumlah duplikasi: ", orderset_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_review_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/order_reviews_dataset.csv")
order_review_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_00d57_row0_col0, #T_00d57_row0_col1, #T_00d57_row0_col2, #T_00d57_row0_col3, #T_00d57_row0_col4, #T_00d57_row0_col5, #T_00d57_row0_col6, #T_00d57_row1_col0, #T_00d57_row1_col1, #T_00d57_row1_col2, #T_00d57_row1_col3, #T_00d57_row1_col4, #T_00d57_row1_col5, #T_00d57_row1_col6, #T_00d57_row2_col0, #T_00d57_row2_col1, #T_00d57_row2_col2, #T_00d57_row2_col3, #T_00d57_row2_col4, #T_00d57_row2_col5, #T_00d57_row2_col6, #T_00d57_row3_col0, #T_00d57_row3_col1, #T_00d57_row3_col2, #T_00d57_row3_col3, #T_00d57_row3_col4, #T_00d57_row3_col5, #T_00d57_row3_col6, #T_00d57_row4_col0, #T_00d57_row4_col1, #T_00d57_row4_col2, #T_00d57_row4_col3, #T_00d57_row4_col4, #T_00d57_row4_col5, #T_00d57_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_00d57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00d57_level0_col0" class="col_heading level0 col0" >review_id</th>
# ...

# %%
order_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_review_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_review_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
print("Jumlah duplikasi: ", order_review_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
datetime_columns = ["review_creation_date", "review_answer_timestamp"]
 
for column in datetime_columns:
  order_review_df[column] = pd.to_datetime(order_review_df[column])

# %%
order_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
order_review_df.review_comment_title.fillna(value="my review", inplace=True)

# %%
order_review_df.review_comment_message.fillna(value="good condition, I like this product", inplace=True)

# %%
order_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
print("Jumlah duplikasi: ", order_review_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_payments_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/order_payments_dataset.csv")
order_payments_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_ae203_row0_col0, #T_ae203_row0_col1, #T_ae203_row0_col2, #T_ae203_row0_col3, #T_ae203_row0_col4, #T_ae203_row1_col0, #T_ae203_row1_col1, #T_ae203_row1_col2, #T_ae203_row1_col3, #T_ae203_row1_col4, #T_ae203_row2_col0, #T_ae203_row2_col1, #T_ae203_row2_col2, #T_ae203_row2_col3, #T_ae203_row2_col4, #T_ae203_row3_col0, #T_ae203_row3_col1, #T_ae203_row3_col2, #T_ae203_row3_col3, #T_ae203_row3_col4, #T_ae203_row4_col0, #T_ae203_row4_col1, #T_ae203_row4_col2, #T_ae203_row4_col3, #T_ae203_row4_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_ae203">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae203_level0_col0" class="col_heading level0 col0" >order_id</th>
#       <th id="T_ae203_level0_col1" class="col_heading level0 col1" >payment_sequential</th>
#       <th id="T_ae203_level0_col2" class="col_heading level0 col2" >payment_type</th>
# ...

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_payments_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_item_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/order_items_dataset.csv")
order_item_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_a8c12_row0_col0, #T_a8c12_row0_col1, #T_a8c12_row0_col2, #T_a8c12_row0_col3, #T_a8c12_row0_col4, #T_a8c12_row0_col5, #T_a8c12_row0_col6, #T_a8c12_row1_col0, #T_a8c12_row1_col1, #T_a8c12_row1_col2, #T_a8c12_row1_col3, #T_a8c12_row1_col4, #T_a8c12_row1_col5, #T_a8c12_row1_col6, #T_a8c12_row2_col0, #T_a8c12_row2_col1, #T_a8c12_row2_col2, #T_a8c12_row2_col3, #T_a8c12_row2_col4, #T_a8c12_row2_col5, #T_a8c12_row2_col6, #T_a8c12_row3_col0, #T_a8c12_row3_col1, #T_a8c12_row3_col2, #T_a8c12_row3_col3, #T_a8c12_row3_col4, #T_a8c12_row3_col5, #T_a8c12_row3_col6, #T_a8c12_row4_col0, #T_a8c12_row4_col1, #T_a8c12_row4_col2, #T_a8c12_row4_col3, #T_a8c12_row4_col4, #T_a8c12_row4_col5, #T_a8c12_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_a8c12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8c12_level0_col0" class="col_heading level0 col0" >order_id</th>
# ...

# %%
order_item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_item_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_item_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_item_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
datetime_columns = ["shipping_limit_date"]
 
for column in datetime_columns:
  order_item_df[column] = pd.to_datetime(order_item_df[column])

# %%
order_item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
orders_item_df = pd.merge(
    left=orderset_df,
    right=order_item_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_item_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_item_payments_df = pd.merge(
    left=orders_item_df,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_item_payments_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_df = pd.merge(
    left=orders_item_payments_df,
    right=order_review_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  4   order_approved_at              119143 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   119143 non-null  datetime64[ns]
#  6   order_delivered_customer_date  119143 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  119143 non-null  datetime64[ns]
#  8   order_item_id                  118310 non-null  float64
#  9   product_id                     118310 non-null  object
#  10  seller_id                      118310 non-null  object
# ...

# %%
orders_df.describe()
# Out:
#             order_purchase_timestamp              order_approved_at  \
# count                         119143                         119143
# mean   2017-12-29 18:36:13.115760128  2017-12-30 13:38:51.231687936
# min              2016-09-04 21:15:19            2016-09-15 12:16:38
# 25%              2017-09-10 20:15:46            2017-09-11 19:10:39
# 50%              2018-01-17 11:59:12            2018-01-17 22:50:09
# 75%              2018-05-03 13:18:30            2018-05-04 02:51:34
# max              2018-10-17 17:30:18            2018-09-03 17:40:06
# std                              NaN                            NaN
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                         119143                         119143
# mean   2018-01-07 18:04:46.392024576  2018-01-20 20:17:10.766574848
# min              2016-10-08 10:34:01            2016-10-11 13:46:32
# 25%              2017-09-18 20:12:14     2017-09-28 18:58:08.500000
# ...

# %%
orders_df.isna().sum()
# Out:
# order_id                           0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                  0
# order_delivered_carrier_date       0
# order_delivered_customer_date      0
# order_estimated_delivery_date      0
# order_item_id                    833
# product_id                       833
# seller_id                        833
# shipping_limit_date              833
# price                            833
# freight_value                    833
# payment_sequential                 3
# payment_type                       3
# payment_installments               3
# payment_value                      3
# review_id                        997
# review_score                     997
# review_comment_title             997
# review_comment_message           997
# review_creation_date             997
# review_answer_timestamp          997
# dtype: int64

# %%
orders_df.payment_sequential.describe()
# Out:
# count    119140.000000
# mean          1.094737
# std           0.730141
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          29.000000
# Name: payment_sequential, dtype: float64

# %%
orders_df.payment_sequential.value_counts()
# Out:
# payment_sequential
# 1.0     113999
# 2.0       3415
# 3.0        658
# 4.0        322
# 5.0        194
# 6.0        136
# 7.0         94
# 8.0         63
# 9.0         51
# 10.0        42
# 11.0        36
# 12.0        28
# 13.0        16
# 14.0        13
# 15.0        11
# 16.0         9
# 18.0         9
# 17.0         9
# 19.0         9
# 21.0         6
# 20.0         6
# 22.0         3
# 25.0         2
# 26.0         2
# 23.0         2
# 24.0         2
# 27.0         1
# 29.0         1
# 28.0         1
# Name: count, dtype: int64

# %%
orders_df[orders_df.payment_sequential.isna()]
# Out:
#                                order_id                       customer_id  \
# 36864  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 36865  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 36866  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 36864    delivered      2016-09-15 12:16:38 2016-09-15 12:16:38
# 36865    delivered      2016-09-15 12:16:38 2016-09-15 12:16:38
# 36866    delivered      2016-09-15 12:16:38 2016-09-15 12:16:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 36864          2016-11-07 17:11:53           2016-11-09 07:47:38
# 36865          2016-11-07 17:11:53           2016-11-09 07:47:38
# 36866          2016-11-07 17:11:53           2016-11-09 07:47:38
#
#       order_estimated_delivery_date  order_item_id  \
# 36864                    2016-10-04            1.0
# ...

# %%
orders_df.payment_sequential.fillna(value=1.000000, inplace=True)

# %%
orders_df.payment_type.fillna(value="credit_card", inplace=True)

# %%
orders_df.payment_installments.fillna(value=3.000000, inplace=True)

# %%
orders_df.payment_value.fillna(value=218.040000, inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                           0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                  0
# order_delivered_carrier_date       0
# order_delivered_customer_date      0
# order_estimated_delivery_date      0
# order_item_id                    833
# product_id                       833
# seller_id                        833
# shipping_limit_date              833
# price                            833
# freight_value                    833
# payment_sequential                 0
# payment_type                       0
# payment_installments               0
# payment_value                      0
# review_id                        997
# review_score                     997
# review_comment_title             997
# review_comment_message           997
# review_creation_date             997
# review_answer_timestamp          997
# dtype: int64

# %%
orders_df.review_id.fillna(value="0c5b33dea94867d1ac402749e5438e8b", inplace=True)

# %%
orders_df.review_score.fillna(value=4.000000 , inplace=True)

# %%
orders_df.review_comment_title.fillna(value="my review", inplace=True)

# %%
orders_df.review_comment_message.fillna(value="good condition, I like this product", inplace=True)

# %%
orders_df.review_creation_date.fillna(value="2018-08-31 00:00:00", inplace=True)

# %%
orders_df.review_answer_timestamp.fillna(value="2018-10-29 12:27:35", inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                           0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                  0
# order_delivered_carrier_date       0
# order_delivered_customer_date      0
# order_estimated_delivery_date      0
# order_item_id                    833
# product_id                       833
# seller_id                        833
# shipping_limit_date              833
# price                            833
# freight_value                    833
# payment_sequential                 0
# payment_type                       0
# payment_installments               0
# payment_value                      0
# review_id                          0
# review_score                       0
# review_comment_title               0
# review_comment_message             0
# review_creation_date               0
# review_answer_timestamp            0
# dtype: int64

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                             119143                            119143
# unique                             99441                             99441
# top     895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# freq                                  63                                63
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
products_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/products_dataset.csv")
products_df.head().style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_87cb9_row0_col0, #T_87cb9_row0_col1, #T_87cb9_row0_col2, #T_87cb9_row0_col3, #T_87cb9_row0_col4, #T_87cb9_row0_col5, #T_87cb9_row0_col6, #T_87cb9_row0_col7, #T_87cb9_row0_col8, #T_87cb9_row1_col0, #T_87cb9_row1_col1, #T_87cb9_row1_col2, #T_87cb9_row1_col3, #T_87cb9_row1_col4, #T_87cb9_row1_col5, #T_87cb9_row1_col6, #T_87cb9_row1_col7, #T_87cb9_row1_col8, #T_87cb9_row2_col0, #T_87cb9_row2_col1, #T_87cb9_row2_col2, #T_87cb9_row2_col3, #T_87cb9_row2_col4, #T_87cb9_row2_col5, #T_87cb9_row2_col6, #T_87cb9_row2_col7, #T_87cb9_row2_col8, #T_87cb9_row3_col0, #T_87cb9_row3_col1, #T_87cb9_row3_col2, #T_87cb9_row3_col3, #T_87cb9_row3_col4, #T_87cb9_row3_col5, #T_87cb9_row3_col6, #T_87cb9_row3_col7, #T_87cb9_row3_col8, #T_87cb9_row4_col0, #T_87cb9_row4_col1, #T_87cb9_row4_col2, #T_87cb9_row4_col3, #T_87cb9_row4_col4, #T_87cb9_row4_col5, #T_87cb9_row4_col6, #T_87cb9_row4_col7, #T_87cb9_row4_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_87cb9">
# ...

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
products_df.product_category_name.fillna(value="unknown", inplace=True)

# %%
products_df.product_name_lenght.fillna(value=51.000000, inplace=True)

# %%
products_df.product_description_lenght.fillna(value=595.000000, inplace=True)

# %%
products_df.product_photos_qty.fillna(value=1.000000, inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              2
# product_length_cm             2
# product_height_cm             2
# product_width_cm              2
# dtype: int64

# %%
products_df[products_df.product_weight_g.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a               unknown
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                 51.0                       595.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
products_df[products_df.product_length_cm.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a               unknown
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                 51.0                       595.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
products_df.product_weight_g.fillna(value=371.000000, inplace=True)

# %%
products_df.product_length_cm.fillna(value=26.000000, inplace=True)

# %%
products_df.product_height_cm.fillna(value=4.000000, inplace=True)

# %%
products_df.product_width_cm.fillna(value=26.000000, inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32951 non-null  object
#  2   product_name_lenght         32951 non-null  float64
#  3   product_description_lenght  32951 non-null  float64
#  4   product_photos_qty          32951 non-null  float64
#  5   product_weight_g            32951 non-null  float64
#  6   product_length_cm           32951 non-null  float64
#  7   product_height_cm           32951 non-null  float64
#  8   product_width_cm            32951 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
product_id = products_df.pop('product_id')
products_df.insert(0, 'product_id', product_id)
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_category_df = pd.read_csv("https://raw.githubusercontent.com/IzzaMooN/DataScientist/main/product_category_name_translation.csv")
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
product_category_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
print("Jumlah duplikasi: ", product_category_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_id = orders_customers_df.pop('product_id')
orders_customers_df.insert(0, 'product_id', product_id)
orders_customers_df.head()
# Out:
#                          product_id                          order_id  \
# 0  87285b34884572647811a353c7ac498a  e481f51cbdc54678b7cc49136f2d6af7
# 1  87285b34884572647811a353c7ac498a  e481f51cbdc54678b7cc49136f2d6af7
# 2  87285b34884572647811a353c7ac498a  e481f51cbdc54678b7cc49136f2d6af7
# 3  595fac2a385ac33a80bd5114aec74eb8  53cdb2fc8bc7dce0b6741e2150273451
# 4  aa4383b373c6aca5d8797843e5594415  47770eb9100c2d0c44946d9cf07ec65d
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 2  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 3  b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 4  41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
#
#     order_approved_at order_delivered_carrier_date  \
# ...

# %%
orders_customers_products_df = pd.merge(
    left=orders_customers_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
orders_customers_products_df.head()
# Out:
#                          product_id                          order_id  \
# 0  87285b34884572647811a353c7ac498a  e481f51cbdc54678b7cc49136f2d6af7
# 1  87285b34884572647811a353c7ac498a  e481f51cbdc54678b7cc49136f2d6af7
# 2  87285b34884572647811a353c7ac498a  e481f51cbdc54678b7cc49136f2d6af7
# 3  595fac2a385ac33a80bd5114aec74eb8  53cdb2fc8bc7dce0b6741e2150273451
# 4  aa4383b373c6aca5d8797843e5594415  47770eb9100c2d0c44946d9cf07ec65d
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 2  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 3  b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 4  41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
#
#     order_approved_at order_delivered_carrier_date  \
# ...

# %%
orders_customers_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   product_id                     118310 non-null  object
#  1   order_id                       119143 non-null  object
#  2   customer_id                    119143 non-null  object
#  3   order_status                   119143 non-null  object
#  4   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  5   order_approved_at              119143 non-null  datetime64[ns]
#  6   order_delivered_carrier_date   119143 non-null  datetime64[ns]
#  7   order_delivered_customer_date  119143 non-null  datetime64[ns]
#  8   order_estimated_delivery_date  119143 non-null  datetime64[ns]
#  9   order_item_id                  118310 non-null  float64
#  10  seller_id                      118310 non-null  object
# ...

# %%
seller_id = orders_customers_products_df.pop('seller_id')
orders_customers_products_df.insert(0, 'seller_id', seller_id)
orders_customers_products_df.head()
# Out:
#                           seller_id                        product_id  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  87285b34884572647811a353c7ac498a
# 1  3504c0cb71d7fa48d967e0e4c94d59d9  87285b34884572647811a353c7ac498a
# 2  3504c0cb71d7fa48d967e0e4c94d59d9  87285b34884572647811a353c7ac498a
# 3  289cdb325fb7e7f891c38608bf9e0962  595fac2a385ac33a80bd5114aec74eb8
# 4  4869f7a5dfa277a7dca6462dcf3b52b2  aa4383b373c6aca5d8797843e5594415
#
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders_customers_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   seller_id                      118310 non-null  object
#  1   product_id                     118310 non-null  object
#  2   order_id                       119143 non-null  object
#  3   customer_id                    119143 non-null  object
#  4   order_status                   119143 non-null  object
#  5   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  6   order_approved_at              119143 non-null  datetime64[ns]
#  7   order_delivered_carrier_date   119143 non-null  datetime64[ns]
#  8   order_delivered_customer_date  119143 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  119143 non-null  datetime64[ns]
#  10  order_item_id                  118310 non-null  float64
# ...

# %%
all_data_df = pd.merge(
    left=orders_customers_products_df,
    right=seller_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
all_data_df.head()
# Out:
#                           seller_id                        product_id  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  87285b34884572647811a353c7ac498a
# 1  3504c0cb71d7fa48d967e0e4c94d59d9  87285b34884572647811a353c7ac498a
# 2  3504c0cb71d7fa48d967e0e4c94d59d9  87285b34884572647811a353c7ac498a
# 3  289cdb325fb7e7f891c38608bf9e0962  595fac2a385ac33a80bd5114aec74eb8
# 4  4869f7a5dfa277a7dca6462dcf3b52b2  aa4383b373c6aca5d8797843e5594415
#
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
all_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   seller_id                      118310 non-null  object
#  1   product_id                     118310 non-null  object
#  2   order_id                       119143 non-null  object
#  3   customer_id                    119143 non-null  object
#  4   order_status                   119143 non-null  object
#  5   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  6   order_approved_at              119143 non-null  datetime64[ns]
#  7   order_delivered_carrier_date   119143 non-null  datetime64[ns]
#  8   order_delivered_customer_date  119143 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  119143 non-null  datetime64[ns]
#  10  order_item_id                  118310 non-null  float64
# ...

# %%
all_data_df.isna().sum()
# Out:
# seller_id                        833
# product_id                       833
# order_id                           0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                  0
# order_delivered_carrier_date       0
# order_delivered_customer_date      0
# order_estimated_delivery_date      0
# order_item_id                    833
# shipping_limit_date              833
# price                            833
# freight_value                    833
# payment_sequential                 0
# payment_type                       0
# payment_installments               0
# payment_value                      0
# review_id                          0
# review_score                       0
# review_comment_title               0
# review_comment_message             0
# review_creation_date               0
# review_answer_timestamp            0
# customer_unique_id                 0
# ...

# %%
all_data_df.describe()
# Out:
#             order_purchase_timestamp              order_approved_at  \
# count                         119143                         119143
# mean   2017-12-29 18:36:13.115760128  2017-12-30 13:38:51.231687936
# min              2016-09-04 21:15:19            2016-09-15 12:16:38
# 25%              2017-09-10 20:15:46            2017-09-11 19:10:39
# 50%              2018-01-17 11:59:12            2018-01-17 22:50:09
# 75%              2018-05-03 13:18:30            2018-05-04 02:51:34
# max              2018-10-17 17:30:18            2018-09-03 17:40:06
# std                              NaN                            NaN
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                         119143                         119143
# mean   2018-01-07 18:04:46.392024576  2018-01-20 20:17:10.766574848
# min              2016-10-08 10:34:01            2016-10-11 13:46:32
# 25%              2017-09-18 20:12:14     2017-09-28 18:58:08.500000
# ...

# %%
all_data_df[all_data_df.seller_id.isna()]
# Out:
#        seller_id product_id                          order_id  \
# 319          NaN        NaN  8e24261a7e58791d10cb1bf9da94df5c
# 702          NaN        NaN  c272bcd21c287498b4883c7512019702
# 828          NaN        NaN  37553832a3a89c9b2db59701c357ca67
# 887          NaN        NaN  d57e15fb07fd180f06ab3926b39edcd2
# 1362         NaN        NaN  00b1cb0320190ca0daa2c88b35206009
# ...          ...        ...                               ...
# 118914       NaN        NaN  aaab15da689073f8f9aa978a390a69d1
# 118946       NaN        NaN  3a3cddda5a7c27851bd96c3313412840
# 119039       NaN        NaN  a89abace0dcc01eeb267a9660b5ac126
# 119040       NaN        NaN  a69ba794cc7deb415c3e15a0a3877e69
# 119112       NaN        NaN  5fabc81b6322c8443648e1b21a6fef21
#
#                              customer_id order_status  \
# 319     64a254d30eed42cd0e6c36dddb88adf0  unavailable
# 702     9582c5bbecc65eb568e2c1d839b5cba1  unavailable
# 828     7607cd563696c27ede287e515812d528  unavailable
# ...

# %%
all_data_df.seller_id.fillna(value="3504c0cb71d7fa48d967e0e4c94d59d9", inplace=True)

# %%
all_data_df.product_id.fillna(value="87285b34884572647811a353c7ac498a", inplace=True)

# %%
all_data_df.order_item_id.fillna(value=1.0, inplace=True)

# %%
all_data_df.shipping_limit_date.fillna(value="2020-04-09 22:35:08", inplace=True)

# %%
all_data_df.price.fillna(value=74.900000, inplace=True)

# %%
all_data_df.freight_value.fillna(value=16.280000, inplace=True)

# %%
all_data_df.product_category_name.fillna(value="unknown", inplace=True)

# %%
all_data_df.product_name_lenght.fillna(value=51.000000, inplace=True)

# %%
all_data_df.product_description_lenght.fillna(value=595.000000, inplace=True)

# %%
all_data_df.product_photos_qty.fillna(value=1.0, inplace=True)

# %%
all_data_df.product_weight_g.fillna(value=700.000000, inplace=True)

# %%
all_data_df.product_length_cm.fillna(value=25.000000, inplace=True)

# %%
all_data_df.product_height_cm.fillna(value=8.000000, inplace=True)

# %%
all_data_df.product_width_cm.fillna(value=30.000000, inplace=True)

# %%
all_data_df.seller_zip_code_prefix.fillna(value=13660.000000, inplace=True)

# %%
all_data_df.seller_city.fillna(value="sao paulo", inplace=True)

# %%
all_data_df.seller_state.fillna(value="SP:", inplace=True)

# %%
all_data_df.isna().sum()
# Out:
# seller_id                        0
# product_id                       0
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# review_answer_timestamp          0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# ...

# %%
"VISUALISASI DATA"
# Out:
# 'VISUALISASI DATA'

# %%
"1) Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?"
# Out:
# '1) Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?'

# %%
all_data_df.groupby(by="product_category_name").agg({
    "seller_id": "nunique",
    "payment_installments": "sum",
    "price": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                                seller_id  payment_installments       price
# product_category_name
# beleza_saude                         492               30337.0  1301947.97
# relogios_presentes                   101               22813.0  1254322.95
# cama_mesa_banho                      196               42725.0  1107249.09
# esporte_lazer                        481               22575.0  1029603.88
# informatica_acessorios               287               18456.0   950053.69
# ...                                  ...                   ...         ...
# flores                                 3                  45.0     1110.04
# casa_conforto_2                        4                  45.0      773.17
# cds_dvds_musicais                      1                  36.0      730.00
# fashion_roupa_infanto_juvenil          4                  15.0      569.85
# seguros_e_servicos                     2                   2.0      283.29
#
# [74 rows x 3 columns]

# %%
sum_order_items_df = all_data_df.groupby("product_category_name").payment_installments.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#      product_category_name  payment_installments
# 0          cama_mesa_banho               42725.0
# 1             beleza_saude               30337.0
# 2         moveis_decoracao               27671.0
# 3       relogios_presentes               22813.0
# 4            esporte_lazer               22575.0
# 5    utilidades_domesticas               21920.0
# 6   informatica_acessorios               18456.0
# 7       ferramentas_jardim               13590.0
# 8               cool_stuff               13024.0
# 9               automotivo               12727.0
# 10              brinquedos               12254.0
# 11              perfumaria               11481.0
# 12               telefonia               10929.0
# 13                   bebes                9257.0
# 14       moveis_escritorio                6860.0

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
 
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
 
sns.barplot(x="payment_installments", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)
 
sns.barplot(x="payment_installments", y="product_category_name", data=sum_order_items_df.sort_values(by="payment_installments", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
 
plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %%
"2) Kapan terakhir pelanggan melakukan transaksi?"
# Out:
# '2) Kapan terakhir pelanggan melakukan transaksi?'

# %%
rfm_df = all_data_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
 
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = all_data_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
 
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      337
# 1  000161a058600d5901f007fab4c27140          1     54.90      458
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      596
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      427
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      198

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(30, 6))
 
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
 
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors)
ax.set_title("By Recency (days)", loc="center", fontsize=18)
ax.tick_params(axis ='x', labelsize=15)

plt.suptitle("Last Transactions (customer_id)", fontsize=20)
plt.show()

# %%
all_data_df.to_csv("all_data.csv", index=False)
